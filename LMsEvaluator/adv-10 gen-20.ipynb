# %%
# %run main.py
# Out:
# /Users/zkzhu/anaconda3/envs/LMs3.9env/lib/python3.9/site-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# [2024-03-20 21:48:00] - INFO: 成功导入BERT配置文件 /Users/zkzhu/Project/PycharmProject/LMsEvaluation/LMs/bert_base_chinese/config.json
# [2024-03-20 21:48:00] - INFO:  ### 将当前配置打印到日志文件中
# [2024-03-20 21:48:00] - INFO: ###  project_dir = /Users/zkzhu/Project/PycharmProject/LMsEvaluation
# [2024-03-20 21:48:00] - INFO: ###  dataset_dir = /Users/zkzhu/Project/PycharmProject/LMsEvaluation/data/imdb
# [2024-03-20 21:48:00] - INFO: ###  pretrained_model_dir = /Users/zkzhu/Project/PycharmProject/LMsEvaluation/LMs/bert_base_chinese
# [2024-03-20 21:48:00] - INFO: ###  vocab_path = /Users/zkzhu/Project/PycharmProject/LMsEvaluation/LMs/bert_base_chinese/vocab.txt
# [2024-03-20 21:48:00] - INFO: ###  device = mps
# ...
